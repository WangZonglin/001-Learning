# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df=pd.read_csv('aa.csv')
df
# Out:
#       A1             A2     A3          A4            A5         A6  \
# 0   PLC8  PLC8-BASE-CIP  21012  1071-X-779   1071-XY-779   FIELDBUS
# 1   PLC8  PLC8-BASE-CIP  21014  1071-X-779  1071-ZSH-779  HARDWIRED
# 2   PLC8  PLC8-BASE-CIP  21016  1071-X-779  1071-ZSL-779  HARDWIRED
# 3   PLC8  PLC8-BASE-CIP  21019  1071-X-780   1071-XY-780   FIELDBUS
# 4   PLC8  PLC8-BASE-CIP  21021  1071-X-780  1071-ZSH-780  HARDWIRED
# 5   PLC8  PLC8-BASE-CIP  21023  1071-X-780  1071-ZSL-780  HARDWIRED
# 6   PLC8  PLC8-BASE-CIP  21026  1072-X-777   1072-XY-777   FIELDBUS
# 7   PLC8  PLC8-BASE-CIP  21028  1072-X-777  1072-ZSH-777  HARDWIRED
# 8   PLC8  PLC8-BASE-CIP  21030  1072-X-777  1072-ZSL-777  HARDWIRED
# 9   PLC8  PLC8-BASE-CIP  21033  1072-X-779   1072-XY-779   FIELDBUS
# 10  PLC8  PLC8-BASE-CIP  21035  1072-X-779  1072-ZSH-779  HARDWIRED
# 11  PLC8  PLC8-BASE-CIP  21037  1072-X-779  1072-ZSL-779  HARDWIRED
#
#               A7  A8   A9 A10
# 0   A21-PB-02-34  EX  F02   B
# ...

# %%
df1=pd.read_excel('aa.xlsx')#默认只能读第一个表单的数据，没数据的行会直接填充NaN, 列名是第一行的数据.
df1
# Out:
#      C1             C2     C3          C4            C5         C6  C7  \
# 0  PLC8  PLC8-BASE-CIP  20995  1070-X-780  1070-ZSL-780  HARDWIRED NaN
# 1  PLC8  PLC8-BASE-CIP  20998  1071-X-776   1071-XY-776   FIELDBUS NaN
# 2  PLC8  PLC8-BASE-CIP  21000  1071-X-776  1071-ZSH-776  HARDWIRED NaN
# 3  PLC8  PLC8-BASE-CIP  21002  1071-X-776  1071-ZSL-776  HARDWIRED NaN
# 4  PLC8  PLC8-BASE-CIP  21005  1071-X-777   1071-XY-777   FIELDBUS NaN
# 5  PLC8  PLC8-BASE-CIP  21007  1071-X-777  1071-ZSH-777  HARDWIRED NaN
# 6  PLC8  PLC8-BASE-CIP  21009  1071-X-777  1071-ZSL-777  HARDWIRED NaN
#
#              C8  C9  C10  C11 C12
# 0  A21-PB-02-34  NO  F02  NaN   B
# 1  A21-PB-02-34  EX  F02  NaN   B
# 2  A21-PB-02-34  NO  F02  NaN   B
# 3  A21-PB-02-34  NO  F02  NaN   B
# 4  A21-PB-02-34  EX  F02  NaN   B
# 5  A21-PB-02-34  NO  F02  NaN   B
# 6  A21-PB-02-34  NO  F02  NaN   B

# %%
df1.to_csv('write1.csv') # 直接数据写到CSV中

# %%
df1.to_html('aa.html')

# %%
df1.to_json('aa.json')

# %% [markdown]
# JSON的章节

# %%
import json

#result=json.loads(obj) #只能用于导入固定JSON数据格式的对象

# %%
data=pd.read_json('aa.json')
print(data.to_json())
# Out:
# {"C1":{"0":"PLC8","1":"PLC8","2":"PLC8","3":"PLC8","4":"PLC8","5":"PLC8","6":"PLC8"},"C2":{"0":"PLC8-BASE-CIP","1":"PLC8-BASE-CIP","2":"PLC8-BASE-CIP","3":"PLC8-BASE-CIP","4":"PLC8-BASE-CIP","5":"PLC8-BASE-CIP","6":"PLC8-BASE-CIP"},"C3":{"0":20995,"1":20998,"2":21000,"3":21002,"4":21005,"5":21007,"6":21009},"C4":{"0":"1070-X-780","1":"1071-X-776","2":"1071-X-776","3":"1071-X-776","4":"1071-X-777","5":"1071-X-777","6":"1071-X-777"},"C5":{"0":"1070-ZSL-780","1":"1071-XY-776","2":"1071-ZSH-776","3":"1071-ZSL-776","4":"1071-XY-777","5":"1071-ZSH-777","6":"1071-ZSL-777"},"C6":{"0":"HARDWIRED","1":"FIELDBUS","2":"HARDWIRED","3":"HARDWIRED","4":"FIELDBUS","5":"HARDWIRED","6":"HARDWIRED"},"C7":{"0":null,"1":null,"2":null,"3":null,"4":null,"5":null,"6":null},"C8":{"0":"A21-PB-02-34","1":"A21-PB-02-34","2":"A21-PB-02-34","3":"A21-PB-02-34","4":"A21-PB-02-34","5":"A21-PB-02-34","6":"A21-PB-02-34"},"C9":{"0":"NO","1":"EX","2":"NO","3":"NO","4":"EX","5":"NO","6":"NO"},"C10":{"0":"F02","1":"F02","
# ...

# %%
tables=pd.read_html('aa.html')
len(tables)
# Out:
# 1

# %%
failures=tables[0]
failures.head()
# Out:
#    Unnamed: 0    C1             C2     C3          C4            C5  \
# 0           0  PLC8  PLC8-BASE-CIP  20995  1070-X-780  1070-ZSL-780
# 1           1  PLC8  PLC8-BASE-CIP  20998  1071-X-776   1071-XY-776
# 2           2  PLC8  PLC8-BASE-CIP  21000  1071-X-776  1071-ZSH-776
# 3           3  PLC8  PLC8-BASE-CIP  21002  1071-X-776  1071-ZSL-776
# 4           4  PLC8  PLC8-BASE-CIP  21005  1071-X-777   1071-XY-777
#
#           C6  C7            C8  C9  C10  C11 C12
# 0  HARDWIRED NaN  A21-PB-02-34  NO  F02  NaN   B
# 1   FIELDBUS NaN  A21-PB-02-34  EX  F02  NaN   B
# 2  HARDWIRED NaN  A21-PB-02-34  NO  F02  NaN   B
# 3  HARDWIRED NaN  A21-PB-02-34  NO  F02  NaN   B
# 4   FIELDBUS NaN  A21-PB-02-34  EX  F02  NaN   B

# %% [markdown]
# XML章节

# %% [markdown]
# 二进制格式 PICKLE化：临时数据
# HDF5 (推荐）
# MESSAGEPACK

# %%
store=pd.HDFStore('mydata.h5')

# %%
pd.read_hdf('mydata.h5','obj5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-576aa0d80fc8> in <module>()
# ----> 1 pd.read_hdf('mydata.h5','obj5')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     371                 'File %s does not exist' % path_or_buf)
#     372
# --> 373         store = HDFStore(path_or_buf, mode=mode, **kwargs)
#     374         # can't auto open/close if we are using an iterator
#     375         # so delegate to the iterator
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     489         self._fletcher32 = fletcher32
#     490         self._filters = None
# --> 491         self.open(mode=mode, **kwargs)
#     492
#     493     def __fspath__(self):
#
# ...

# %% [markdown]
# EXCEL读写

# %%
xlsx=pd.ExcelFile('aa.xlsx')
frame=pd.read_excel(xlsx,'S1') #读取指定目标表格的数据
frame
# Out:
#      C1             C2     C3          C4            C5         C6  C7  \
# 0  PLC8  PLC8-BASE-CIP  20995  1070-X-780  1070-ZSL-780  HARDWIRED NaN
# 1  PLC8  PLC8-BASE-CIP  20998  1071-X-776   1071-XY-776   FIELDBUS NaN
# 2  PLC8  PLC8-BASE-CIP  21000  1071-X-776  1071-ZSH-776  HARDWIRED NaN
# 3  PLC8  PLC8-BASE-CIP  21002  1071-X-776  1071-ZSL-776  HARDWIRED NaN
# 4  PLC8  PLC8-BASE-CIP  21005  1071-X-777   1071-XY-777   FIELDBUS NaN
# 5  PLC8  PLC8-BASE-CIP  21007  1071-X-777  1071-ZSH-777  HARDWIRED NaN
# 6  PLC8  PLC8-BASE-CIP  21009  1071-X-777  1071-ZSL-777  HARDWIRED NaN
#
#              C8  C9  C10  C11 C12
# 0  A21-PB-02-34  NO  F02  NaN   B
# 1  A21-PB-02-34  EX  F02  NaN   B
# 2  A21-PB-02-34  NO  F02  NaN   B
# 3  A21-PB-02-34  NO  F02  NaN   B
# 4  A21-PB-02-34  EX  F02  NaN   B
# 5  A21-PB-02-34  NO  F02  NaN   B
# 6  A21-PB-02-34  NO  F02  NaN   B

# %%
writer=pd.ExcelWriter('bb1.xlsx')
frame.to_excel(writer,'sheet11') #可以定义新EXCEL表格的SHEET名称
writer.save()

# %% [markdown]
# WEB API

# %%
import requests
url='http://api.github.com/repos/pandas-dev/pandas/issues'
#url='https://www.baidu.com/'
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
data[1]['title'] 
issues=pd.DataFrame(data,columns=['title','state','locked'])
issues
# Out:
#                                                 title state  locked
# 0   resample using for subsample will regards NaN ...  open   False
# 1         MemoryError when using `.drop_duplicates()`  open   False
# 2       TST: new test for incorrect series assignment  open   False
# 3            CLN: deprivatize factorize_from_iterable  open   False
# 4   TST: new test for sort index when Nan in other...  open   False
# 5                       Deprecate using `xlrd` engine  open   False
# 6                      Updated index links for 0.25.3  open   False
# 7             Add documentation linking to sqlalchemy  open   False
# 8   TST: new test for str to small float conversio...  open   False
# 9   TST: Adding merge test for non-string columns ...  open   False
# 10                                      Fix pipe docs  open   False
# 11  29213: Dataframe Constructor from List of List...  open   False
# 12                Test added: uint64 multicolumn sort  open   False
# ...

# %% [markdown]
# SQL 的连接和数据抽取?? 如何连接到SQL数据库待定？？？？

# %%
import sqlite3
query="""
    CREATE TABLE TEST
    (a VARCHAR(20),B VARCHAR(20),C VARCHAR(20),D VARCHAR(20))
    );"""
con=sqlite3.connect('mydata.sqlite')
con.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-90-f717b4951896> in <module>()
#       5     );"""
#       6 con=sqlite3.connect('mydata.sqlite')
# ----> 7 con.execute(query)
#
# OperationalError: near ")": syntax error

# %%
import sqlalchemy as sqla
db=sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test', db)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# OperationalError: no such table: test
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-91-444a142d768c> in <module>()
# ...
